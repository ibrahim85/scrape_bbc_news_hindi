# %%
# !pip install scrapy
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      |████████████████████████████████| 238 kB 3.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 10.9 MB/s eta 0:00:01     |████████████████████████████▍   | 2.7 MB 10.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.7 MB 14.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.2 MB 36.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 169 kB 64.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51 kB 1.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 7.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 42.8 MB/s eta 0:00:01
# ...

# %%
# !scrapy crawl NewsCrawler
# Out:
# 2020-02-04 19:21:25 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: BBC_NewsHindi)
# 2020-02-04 19:21:25 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.14.138+-x86_64-with-debian-buster-sid
# 2020-02-04 19:21:25 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'BBC_NewsHindi', 'NEWSPIDER_MODULE': 'BBC_NewsHindi.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['BBC_NewsHindi.spiders']}
# 2020-02-04 19:21:25 [scrapy.extensions.telnet] INFO: Telnet Password: 5dd7f2b9d0e8ff86
# 2020-02-04 19:21:25 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
# !scrapy crawl RecentDayNewsCrawler
# Out:
# 2020-02-04 20:42:35 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: BBC_NewsHindi)
# 2020-02-04 20:42:35 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.6 | packaged by conda-forge | (default, Jan  7 2020, 22:33:48) - [GCC 7.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.14.138+-x86_64-with-debian-buster-sid
# 2020-02-04 20:42:35 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'BBC_NewsHindi', 'NEWSPIDER_MODULE': 'BBC_NewsHindi.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['BBC_NewsHindi.spiders']}
# 2020-02-04 20:42:35 [scrapy.extensions.telnet] INFO: Telnet Password: 6a2806db9488acc7
# 2020-02-04 20:42:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
